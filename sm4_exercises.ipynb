# %% [markdown]
# # Exercises: SM4 from scratch in Python
#
# This notebook accompanies the post **SM4 from scratch: implementing the algorithm in Python**.
#
# Constants and the S-box are already in `sm4.py`. You implement the functions for each exercise. Tests live in the same file.

# %%
############## RUN THIS CELL FIRST ###################

from importlib import reload

from helper import run
import sm4

# %% [markdown]
# ### Exercise 1
#
# Rotate a 32-bit word to the left.
#
# Pass: `sm4.py:Sm4Test:test_rotl`

# %%
# Exercise 1

reload(sm4)

def rotl(a, n):
    # implement here
    pass

sm4.rotl = rotl

run(sm4.Sm4Test("test_rotl"))

# %% [markdown]
# ### Exercise 2
#
# Convert 4 bytes ↔ 32-bit word (big-endian).
#
# Pass: `sm4.py:Sm4Test:test_load_store`

# %%
# Exercise 2

reload(sm4)

def load_u32_be(b, n):
    # implement here
    pass

def store_u32_be(v):
    # implement here
    pass

sm4.load_u32_be = load_u32_be
sm4.store_u32_be = store_u32_be

run(sm4.Sm4Test("test_load_store"))

# %% [markdown]
# ### Exercise 3
#
# Implement `SM4_T_non_lin_sub(X)`: apply `SM4_S` to each of the 4 bytes.
#
# Pass: `sm4.py:Sm4Test:test_SM4_T_non_lin_sub`

# %%
# Exercise 3

reload(sm4)

def SM4_T_non_lin_sub(X):
    # implement here
    pass

sm4.SM4_T_non_lin_sub = SM4_T_non_lin_sub

run(sm4.Sm4Test("test_SM4_T_non_lin_sub"))

# %% [markdown]
# ### Exercise 4
#
# Implement `SM4_T_slow(X)` (S-box + L with rotations 2,10,18,24).
#
# Pass: `sm4.py:Sm4Test:test_SM4_T_slow`

# %%
# Exercise 4

reload(sm4)

def SM4_T_slow(X):
    # implement here
    pass

sm4.SM4_T_slow = SM4_T_slow

run(sm4.Sm4Test("test_SM4_T_slow"))

# %% [markdown]
# ### Exercise 5
#
# Implement `SM4_key_sub(X)` (S-box + L' with rotations 13,23).
#
# Pass: `sm4.py:Sm4Test:test_SM4_key_sub`

# %%
# Exercise 5

reload(sm4)

def SM4_key_sub(X):
    # implement here
    pass

sm4.SM4_key_sub = SM4_key_sub

run(sm4.Sm4Test("test_SM4_key_sub"))

# %% [markdown]
# ### Exercise 6
#
# Implement `ossl_sm4_set_key(key)` and produce the 32 round keys.
#
# Pass: `sm4.py:Sm4Test:test_ossl_sm4_set_key`

# %%
# Exercise 6

reload(sm4)

def ossl_sm4_set_key(key):
    # implement here
    pass

sm4.ossl_sm4_set_key = ossl_sm4_set_key

run(sm4.Sm4Test("test_ossl_sm4_set_key"))

# %% [markdown]
# ### Exercise 7
#
# Implement `ossl_sm4_encrypt(in_bytes, key)` (32 rounds + final reverse).
#
# Pass: `sm4.py:Sm4Test:test_ossl_sm4_encrypt`

# %%
# Exercise 7

reload(sm4)

def ossl_sm4_encrypt(in_bytes, key):
    # implement here
    pass

sm4.ossl_sm4_encrypt = ossl_sm4_encrypt

run(sm4.Sm4Test("test_ossl_sm4_encrypt"))

# %% [markdown]
# ### Exercise 8
#
# Implement `ossl_sm4_decrypt(in_bytes, key)`: same structure, `rk` in reverse order.
#
# Pass: `sm4.py:Sm4Test:test_ossl_sm4_decrypt`

# %%
# Exercise 8

reload(sm4)

def ossl_sm4_decrypt(in_bytes, key):
    # implement here
    pass

sm4.ossl_sm4_decrypt = ossl_sm4_decrypt

run(sm4.Sm4Test("test_ossl_sm4_decrypt"))
