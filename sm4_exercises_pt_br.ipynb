# %% [markdown]
# # Exercícios: SM4 do zero em Python
#
# Este notebook acompanha o post **SM4 do zero: implementando o algoritmo em Python**.
#
# As tabelas (`SM4_S`, `FK`, `CK`) já estão em `sm4.py`. Você implementa as funções de cada exercício. Os testes ficam no mesmo arquivo.

# %%
############## EXECUTE ESTA CÉLULA PRIMEIRO ###################

from importlib import reload

from helper import run
import sm4

# %% [markdown]
# ### Exercício 1
#
# Rotacione a palavra de 32 bits para a esquerda.
#
# Faça passar: `sm4.py:Sm4Test:test_rotl`

# %%
# Exercício 1

reload(sm4)

def rotl(a, n):
    # implemente aqui
    pass

sm4.rotl = rotl

run(sm4.Sm4Test("test_rotl"))

# %% [markdown]
# ### Exercício 2
#
# Converta 4 bytes ↔ palavra de 32 bits (big-endian).
#
# Faça passar: `sm4.py:Sm4Test:test_load_store`

# %%
# Exercício 2

reload(sm4)

def load_u32_be(b, n):
    # implemente aqui
    pass

def store_u32_be(v):
    # implemente aqui
    pass

sm4.load_u32_be = load_u32_be
sm4.store_u32_be = store_u32_be

run(sm4.Sm4Test("test_load_store"))

# %% [markdown]
# ### Exercício 3
#
# Implemente `SM4_T_non_lin_sub(X)`: aplique `SM4_S` em cada um dos 4 bytes.
#
# Faça passar: `sm4.py:Sm4Test:test_SM4_T_non_lin_sub`

# %%
# Exercício 3

reload(sm4)

def SM4_T_non_lin_sub(X):
    # implemente aqui
    pass

sm4.SM4_T_non_lin_sub = SM4_T_non_lin_sub

run(sm4.Sm4Test("test_SM4_T_non_lin_sub"))

# %% [markdown]
# ### Exercício 4
#
# Implemente `SM4_T_slow(X)` (S-box + L com rotações 2,10,18,24).
#
# Faça passar: `sm4.py:Sm4Test:test_SM4_T_slow`

# %%
# Exercício 4

reload(sm4)

def SM4_T_slow(X):
    # implemente aqui
    pass

sm4.SM4_T_slow = SM4_T_slow

run(sm4.Sm4Test("test_SM4_T_slow"))

# %% [markdown]
# ### Exercício 5
#
# Implemente `SM4_key_sub(X)` (S-box + L' com rotações 13,23).
#
# Faça passar: `sm4.py:Sm4Test:test_SM4_key_sub`

# %%
# Exercício 5

reload(sm4)

def SM4_key_sub(X):
    # implemente aqui
    pass

sm4.SM4_key_sub = SM4_key_sub

run(sm4.Sm4Test("test_SM4_key_sub"))

# %% [markdown]
# ### Exercício 6
#
# Implemente `ossl_sm4_set_key(key)` e gere as 32 chaves de rodada.
#
# Faça passar: `sm4.py:Sm4Test:test_ossl_sm4_set_key`

# %%
# Exercício 6

reload(sm4)

def ossl_sm4_set_key(key):
    # implemente aqui
    pass

sm4.ossl_sm4_set_key = ossl_sm4_set_key

run(sm4.Sm4Test("test_ossl_sm4_set_key"))

# %% [markdown]
# ### Exercício 7
#
# Implemente `ossl_sm4_encrypt(in_bytes, key)` (32 rodadas + inversão final).
#
# Faça passar: `sm4.py:Sm4Test:test_ossl_sm4_encrypt`

# %%
# Exercício 7

reload(sm4)

def ossl_sm4_encrypt(in_bytes, key):
    # implemente aqui
    pass

sm4.ossl_sm4_encrypt = ossl_sm4_encrypt

run(sm4.Sm4Test("test_ossl_sm4_encrypt"))

# %% [markdown]
# ### Exercício 8
#
# Implemente `ossl_sm4_decrypt(in_bytes, key)`: mesma estrutura, `rk` na ordem inversa.
#
# Faça passar: `sm4.py:Sm4Test:test_ossl_sm4_decrypt`

# %%
# Exercício 8

reload(sm4)

def ossl_sm4_decrypt(in_bytes, key):
    # implemente aqui
    pass

sm4.ossl_sm4_decrypt = ossl_sm4_decrypt

run(sm4.Sm4Test("test_ossl_sm4_decrypt"))
